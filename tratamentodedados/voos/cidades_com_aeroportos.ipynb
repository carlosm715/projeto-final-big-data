# %%
file = open(file='cidades_com_aeroportos.txt',mode='r', encoding='utf8')

# %%
cidades_por_estado = dict()

ultima_chave = ""
for linha in file:
    linha = linha.strip()
    if linha:
        linha = linha.split("–")
        print(len(linha))
        if len(linha) == 1:
            ultima_chave = linha[0]
            print('Chave:',ultima_chave)
            cidades_por_estado[ultima_chave] = []
        else:
            cidade = linha[-1]
            if cidade not in cidades_por_estado[ultima_chave]:
                cidades_por_estado[ultima_chave].append(linha[-1])
                print('Chave:',ultima_chave,' adicionando valor:',linha[-1])
            else:
                print('Chave:', ultima_chave, ' valor repetido', cidade)
# Out:
# 1
# Chave: Acre
# 2
# Chave: Acre  adicionando valor:  Cruzeiro do Sul
# 2
# Chave: Acre  adicionando valor:  Rio Branco
# 1
# Chave: Alagoas
# 2
# Chave: Alagoas  adicionando valor:  Maceió
# 1
# Chave: Amapá
# 2
# Chave: Amapá  adicionando valor:  Macapá
# 1
# Chave: Amazonas
# 2
# Chave: Amazonas  adicionando valor:  Tefé
# 2
# Chave: Amazonas  adicionando valor:  Tabatinga
# 2
# Chave: Amazonas  adicionando valor:  Manaus
# 1
# Chave: Bahia
# 2
# Chave: Bahia  adicionando valor:  Bom Jesus da Lapa
# 2
# Chave: Bahia  adicionando valor:  Ilhéus
# 2
# Chave: Bahia  adicionando valor:  Paulo Afonso
# 2
# Chave: Bahia  adicionando valor:  Salvador
# 1
# Chave: Ceará
# 2
# Chave: Ceará  adicionando valor:  Fortaleza
# 2
# Chave: Ceará  adicionando valor:  Juazeiro do Norte
# 1
# Chave: Distrito Federal
# 2
# Chave: Distrito Federal  adicionando valor:  Brasília
# 1
# Chave: Espírito Santo
# 2
# Chave: Espírito Santo  adicionando valor:  Vitória
# 1
# Chave: Goiás
# 2
# Chave: Goiás  adicionando valor:  Goiânia
# 2
# Chave: Goiás  adicionando valor:  Caldas Novas
# 1
# Chave: Maranhão
# 2
# Chave: Maranhão  adicionando valor:  Imperatriz
# 2
# Chave: Maranhão  adicionando valor:  São Luís
# 2
# Chave: Maranhão  adicionando valor:  Alcântara
# 1
# Chave: Mato Grosso
# 2
# Chave: Mato Grosso  adicionando valor:  Várzea Grande/Cuiabá
# 1
# Chave: Mato Grosso do Sul
# 2
# Chave: Mato Grosso do Sul  adicionando valor:  Campo Grande
# 2
# Chave: Mato Grosso do Sul  adicionando valor:  Corumbá
# 2
# Chave: Mato Grosso do Sul  adicionando valor:  Ponta Porã
# 1
# Chave: Minas Gerais
# 2
# Chave: Minas Gerais  adicionando valor:  Uberlândia
# 2
# Chave: Minas Gerais  adicionando valor:  Confins/Belo Horizonte
# 3
# Chave: Minas Gerais  adicionando valor:  Belo Horizonte
# 2
# Chave: Minas Gerais  valor repetido  Belo Horizonte
# 2
# Chave: Minas Gerais  adicionando valor:  Montes Claros
# 2
# Chave: Minas Gerais  adicionando valor:  Poços de Caldas
# 2
# Chave: Minas Gerais  adicionando valor:  Uberaba
# 1
# Chave: Paraíba
# 2
# Chave: Paraíba  adicionando valor:  João Pessoa
# 2
# Chave: Paraíba  adicionando valor:  Campina Grande
# 1
# Chave: Pará
# 2
# Chave: Pará  adicionando valor:  Altamira
# 2
# Chave: Pará  adicionando valor:  Belém
# 2
# Chave: Pará  valor repetido  Belém
# 2
# Chave: Pará  adicionando valor:  Marabá
# 2
# Chave: Pará  adicionando valor:  Parauapebas
# 2
# Chave: Pará  adicionando valor:  Santarém
# 1
# Chave: Paraná
# 2
# Chave: Paraná  adicionando valor:  Londrina
# 2
# Chave: Paraná  adicionando valor:  São José dos Pinhais/Curitiba
# 2
# Chave: Paraná  adicionando valor:  Curitiba
# 2
# Chave: Paraná  adicionando valor:  Foz do Iguaçu
# 1
# Chave: Pernambuco
# 3
# Chave: Pernambuco  adicionando valor:  (Petrolina)
# 2
# Chave: Pernambuco  adicionando valor:  Recife
# 1
# Chave: Piauí
# 2
# Chave: Piauí  adicionando valor:  Parnaíba
# 2
# Chave: Piauí  adicionando valor:  Teresina
# 1
# Chave: Rio de Janeiro
# 2
# Chave: Rio de Janeiro  adicionando valor:  Campos dos Goytacazes
# 2
# Chave: Rio de Janeiro  adicionando valor:  Macaé
# 3
# Chave: Rio de Janeiro  adicionando valor:  Rio de Janeiro
# 2
# Chave: Rio de Janeiro  valor repetido  Rio de Janeiro
# 2
# Chave: Rio de Janeiro  adicionando valor:  Rio de Janeiro (cidade)
# 1
# Chave: Rio Grande do Norte
# 2
# Chave: Rio Grande do Norte  adicionando valor:  Parnamirim/Natal
# 1
# Chave: Rio Grande do Sul
# 2
# Chave: Rio Grande do Sul  adicionando valor:  Bagé
# 2
# Chave: Rio Grande do Sul  adicionando valor:  Pelotas
# 2
# Chave: Rio Grande do Sul  adicionando valor:  Porto Alegre
# 2
# Chave: Rio Grande do Sul  adicionando valor:  Uruguaiana
# 1
# Chave: Rondônia
# 1
# Chave: Infraero
# 2
# Chave: Infraero  adicionando valor:  Porto Velho
# 1
# Chave: Municipais
# 2
# Chave: Municipais  adicionando valor:  Ariquemes
# 2
# Chave: Municipais  valor repetido  Ariquemes
# 2
# Chave: Municipais  adicionando valor:  Vilhena
# 2
# Chave: Municipais  adicionando valor:  Cacoal
# 2
# Chave: Municipais  adicionando valor:  Costa Marques
# 2
# Chave: Municipais  adicionando valor:  Guajará-Mirim
# 2
# Chave: Municipais  adicionando valor:  Ji-Paraná
# 2
# Chave: Municipais  adicionando valor:  Pimenta Bueno
# 1
# Chave: Roraima
# 1
# Chave: Infraero
# 3
# Chave: Infraero  adicionando valor:  Boa Vista
# 1
# Chave: Municipais
# 2
# Chave: Municipais  adicionando valor:  Alto Alegre
# 2
# Chave: Municipais  valor repetido  Alto Alegre
# 2
# Chave: Municipais  adicionando valor:  Amajari
# 2
# Chave: Municipais  adicionando valor:  Caracaraí
# 2
# Chave: Municipais  adicionando valor:  Mucajaí
# 2
# Chave: Municipais  adicionando valor:  Pacaraima
# 1
# Chave: Santa Catarina
# 2
# Chave: Santa Catarina  adicionando valor:  Florianópolis
# 2
# Chave: Santa Catarina  adicionando valor:  Navegantes
# 2
# Chave: Santa Catarina  adicionando valor:  Joinville
# 2
# Chave: Santa Catarina  adicionando valor:  Forquilhinha/Criciúma
# 1
# Chave: São Paulo
# 2
# Chave: São Paulo  adicionando valor:  São Paulo
# 2
# Chave: São Paulo  valor repetido  São Paulo
# 2
# Chave: São Paulo  adicionando valor:  Guarulhos / São Paulo
# 2
# Chave: São Paulo  adicionando valor:  Campinas
# 2
# Chave: São Paulo  adicionando valor:  São José dos Campos
# 1
# Chave: Sergipe
# 2
# Chave: Sergipe  adicionando valor:  Aracaju
# 1
# Chave: Tocantins
# 2
# Chave: Tocantins  adicionando valor:  Palmas

# %%
cidades_por_estado
# Out:
# {'Acre': [' Cruzeiro do Sul', ' Rio Branco'],
#  'Alagoas': [' Maceió'],
#  'Amapá': [' Macapá'],
#  'Amazonas': [' Tefé', ' Tabatinga', ' Manaus'],
#  'Bahia': [' Bom Jesus da Lapa', ' Ilhéus', ' Paulo Afonso', ' Salvador'],
#  'Ceará': [' Fortaleza', ' Juazeiro do Norte'],
#  'Distrito Federal': [' Brasília'],
#  'Espírito Santo': [' Vitória'],
#  'Goiás': [' Goiânia', ' Caldas Novas'],
#  'Infraero': [' Boa Vista'],
#  'Maranhão': [' Imperatriz', ' São Luís', ' Alcântara'],
#  'Mato Grosso': [' Várzea Grande/Cuiabá'],
#  'Mato Grosso do Sul': [' Campo Grande', ' Corumbá', ' Ponta Porã'],
#  'Minas Gerais': [' Uberlândia',
#   ' Confins/Belo Horizonte',
#   ' Belo Horizonte',
#   ' Belo Horizonte',
#   ' Montes Claros',
#   ' Poços de Caldas',
#   ' Uberaba'],
#  'Municipais': [' Alto Alegre',
#   ' Alto Alegre',
#   ' Amajari',
#   ' Caracaraí',
#   ' Mucajaí',
#   ' Pacaraima'],
#  'Paraná': [' Londrina',
#   ' São José dos Pinhais/Curitiba',
#   ' Curitiba',
#   ' Foz do Iguaçu'],
#  'Paraíba': [' João Pessoa', ' Campina Grande'],
#  'Pará': [' Altamira',
#   ' Belém',
#   ' Belém',
#   ' Marabá',
#   ' Parauapebas',
#   ' Santarém'],
#  'Pernambuco': [' (Petrolina)', ' Recife'],
#  'Piauí': [' Parnaíba', ' Teresina'],
#  'Rio Grande do Norte': [' Parnamirim/Natal'],
#  'Rio Grande do Sul': [' Bagé', ' Pelotas', ' Porto Alegre', ' Uruguaiana'],
#  'Rio de Janeiro': [' Campos dos Goytacazes',
#   ' Macaé',
#   ' Rio de Janeiro',
#   ' Rio de Janeiro',
#   ' Rio de Janeiro (cidade)'],
#  'Rondônia': [],
#  'Roraima': [],
#  'Santa Catarina': [' Florianópolis',
#   ' Navegantes',
#   ' Joinville',
#   ' Forquilhinha/Criciúma'],
#  'Sergipe': [' Aracaju'],
#  'São Paulo': [' São Paulo',
#   ' São Paulo',
#   ' Guarulhos / São Paulo',
#   ' Campinas',
#   ' São José dos Campos'],
#  'Tocantins': [' Palmas']}

# %%
for estado in cidades_por_estado.items():
    print(estado[0])
    print()
    for cidade in estado[1]:
        print(cidade)
    print()
# Out:
# Acre
#
#  Cruzeiro do Sul
#  Rio Branco
#
# Alagoas
#
#  Maceió
#
# Amapá
#
#  Macapá
#
# Amazonas
#
#  Tefé
#  Tabatinga
#  Manaus
#
# Bahia
#
#  Bom Jesus da Lapa
#  Ilhéus
#  Paulo Afonso
#  Salvador
#
# Ceará
#
#  Fortaleza
#  Juazeiro do Norte
#
# Distrito Federal
#
#  Brasília
#
# Espírito Santo
#
#  Vitória
#
# Goiás
#
#  Goiânia
#  Caldas Novas
#
# Maranhão
#
#  Imperatriz
#  São Luís
#  Alcântara
#
# Mato Grosso
#
#  Várzea Grande/Cuiabá
#
# Mato Grosso do Sul
#
#  Campo Grande
#  Corumbá
#  Ponta Porã
#
# Minas Gerais
#
#  Uberlândia
#  Confins/Belo Horizonte
#  Belo Horizonte
#  Montes Claros
#  Poços de Caldas
#  Uberaba
#
# Paraíba
#
#  João Pessoa
#  Campina Grande
#
# Pará
#
#  Altamira
#  Belém
#  Marabá
#  Parauapebas
#  Santarém
#
# Paraná
#
#  Londrina
#  São José dos Pinhais/Curitiba
#  Curitiba
#  Foz do Iguaçu
#
# Pernambuco
#
#  (Petrolina)
#  Recife
#
# Piauí
#
#  Parnaíba
#  Teresina
#
# Rio de Janeiro
#
#  Campos dos Goytacazes
#  Macaé
#  Rio de Janeiro
#  Rio de Janeiro (cidade)
#
# Rio Grande do Norte
#
#  Parnamirim/Natal
#
# Rio Grande do Sul
#
#  Bagé
#  Pelotas
#  Porto Alegre
#  Uruguaiana
#
# Rondônia
#
#
# Infraero
#
#  Boa Vista
#
# Municipais
#
#  Alto Alegre
#  Amajari
#  Caracaraí
#  Mucajaí
#  Pacaraima
#
# Roraima
#
#
# Santa Catarina
#
#  Florianópolis
#  Navegantes
#  Joinville
#  Forquilhinha/Criciúma
#
# São Paulo
#
#  São Paulo
#  Guarulhos / São Paulo
#  Campinas
#  São José dos Campos
#
# Sergipe
#
#  Aracaju
#
# Tocantins
#
#  Palmas
